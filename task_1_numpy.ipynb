# %%
import cv2
import numpy as np

# %%
from matplotlib import pyplot as plt
im = cv2.imread("big.jpg")
height, width = im.shape[:2]

plt.imshow(im)

# %%
print(height*width)
# Out:
# 187500

# %%
b, g, r = cv2.split(im)

B = np.mean(b) 
G = np.mean(g)
R = np.mean(r)

print(R)
# Out:
# 128.69120533333333

# %%
B_div = np.std(b)
G_div = np.std(g)
R_div = np.std(r)
B_div
# Out:
# 38.29606241503853

# %%
img = np.swapaxes(im, 0, 2)
img[0,345,0]
# Out:
# 90

# %%
np.random.seed(7964)
A = np.random.randint(0, 8, size=(500, 500))

# %%
num_of_7 = A.max(axis=0) == 7
num_of_7.size
# Out:
# 500

# %%
np.argwhere(A<4).sum()
# Out:
# 62383552

# %%
np.argwhere((A<4)&(A>1)).sum()
# Out:
# 31139828

# %%
np.sum((A<4)&(A>1))
# Out:
# 62462

# %%
np.sum(A==3)*3+np.sum(A==2)*2
# Out:
# 156096

# %%
A.max(axis=0).sum()
# Out:
# 3500

# %%
x = np.arange(1, 501, 1)

# %%
np.dot(A,x).sum()
# Out:
# 218833635

# %%
np.random.seed(33)

w = np.random.randint(0, 8, size=(5, 500))

# %%
np.dot(A,w.transpose()).sum()
# Out:
# 15215957

# %%
w1=w
for _ in range(99):
    w = np.vstack((w1,w))
(A*w).sum()
# Out:
# 3045726
